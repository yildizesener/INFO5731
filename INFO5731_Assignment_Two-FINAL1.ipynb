# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %%
from collections import Counter
from spacy import displacy
import scrapy
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from textblob import Word
import spacy
import nltk
# nltk.download('wordnet') # already downloaded
# load spaCy model
nlp = spacy.load("en_core_web_sm")
pd.set_option('max_colwidth', 60) # adjust column with of dataframe

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [2019 Dell labtop](https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/dp/B07N49F51N/ref=sr_1_11?crid=1IJ7UWF2F4GHH&keywords=dell%2Bxps%2B15&qid=1580173569&sprefix=dell%2Caps%2C181&sr=8-11&th=1) on amazon.
#
# (2) Collect the top 100 User Reviews of the film [Joker](https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv) from IMDB.
#
# (3) Collect the abstracts of the top 100 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (4) Collect the top 100 tweets by using hashtag ["#CovidVaccine"](https://twitter.com/hashtag/CovidVaccine) from Twitter.

# %%
# Write your code here
# scraping script modified according to amazon.com

# Creating a new class to implement Spide

class AmazonReviewsSpider(scrapy.Spider):
    # Spider name
    name = 'amazon_reviews'
    # Domain names to scrape
    allowed_domains = ['amazon.com']
    # Base URL for the MacBook air reviews
    start_urls = []
    start_urls.append(
        'https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/product-reviews/B07N49F51N/ref=cm_cr_othr_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'
    )
    myBaseUrl = 'https://www.amazon.com/Dell-Inspiron-5000-5570-Laptop/product-reviews/B07N49F51N/ref=cm_cr_getr_d_paging_btm_next_'
    add_on = '?ie=UTF8&reviewerType=all_reviews&pageNumber='
    # Creating list of urls to be scraped by appending page number a the end of base url
    for i in range(2, 20):
        start_urls.append(myBaseUrl + str(i) + add_on + str(i))
    # Defining a Scrapy parser

    def parse(self, response):
        data = response.css('#cm_cr-review_list')
        # Collecting product star ratings
        star_rating = data.css('.review-rating')
        # Collecting user reviews
        comments = data.css('.review-text')
        count = 0
        # Combining the results
        for review in star_rating:
            yield {
                'stars':
                ''.join(review.xpath('.//text()').extract()),
                'comment':
                ''.join(str(comments[count].xpath(".//text()").extract()))
            }
            count = count + 1
# It saves the reviews to reviews.csv file

# %%
df = pd.read_csv('reviews.csv', header=0, names=['rating', 'reviews']) # read the data (reviews) into a data frame
df.head()
# Out:
#                rating  \
# 0  1.0 out of 5 stars
# 1  1.0 out of 5 stars
# 2  1.0 out of 5 stars
# 3  4.0 out of 5 stars
# 4  2.0 out of 5 stars
#
#                                                        reviews
# 0  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  I purchased th...
# 1  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', "\n  The item came ...
# 2  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  It has already...
# 3  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', "\n  Came in evenin...
# 4  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  This laptop wa...

# %%
# check if there is any duplicated review
print(f'Number of duplicate reviews: {df[df.duplicated() == True].shape[0]}')
# Out:
# Number of duplicate reviews: 0

# %%
# clean the comments
df['reviews_clean'] = df['reviews'].apply(lambda x: x.replace(r"'", ''))
df['reviews_clean'] = df['reviews_clean'].apply(lambda x: x.replace(r'"', ''))
df['reviews_clean'] = df['reviews_clean'].apply(
    lambda x: x.replace(r'[\n\n\n\n\n\n\n\n\n\n  \n  \n    , \n  ', ''))
df['reviews_clean'] = df['reviews_clean'].apply(
    lambda x: x.replace(r'\n, \n  \n]', ''))
df.head()
# Out:
#                rating  \
# 0  1.0 out of 5 stars
# 1  1.0 out of 5 stars
# 2  1.0 out of 5 stars
# 3  4.0 out of 5 stars
# 4  2.0 out of 5 stars
#
#                                                        reviews  \
# 0  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  I purchased th...
# 1  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', "\n  The item came ...
# 2  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  It has already...
# 3  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', "\n  Came in evenin...
# 4  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  This laptop wa...
#
#                                                  reviews_clean
# 0  I purchased this laptop with upgraded RAM (32GB) and SSD...
# 1  The item came promptly. From the beginning the touch scr...
# 2  It has already had issues that require repair beyond the...
# 3  Came in evening around 11pm so in thankful USPS was stil...
# 4  This laptop was ok for the price. Lack of USB-C is a pro...

# %%
# quantify the ratings
df['rating'].replace(sorted(df['rating'].unique()), value=np.arange(1, 6), inplace=True)
df.head()
# Out:
#    rating                                                      reviews  \
# 0       1  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  I purchased th...
# 1       1  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', "\n  The item came ...
# 2       1  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  It has already...
# 3       4  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', "\n  Came in evenin...
# 4       2  ['\n\n\n\n\n\n\n\n\n\n  \n  \n    ', '\n  This laptop wa...
#
#                                                  reviews_clean
# 0  I purchased this laptop with upgraded RAM (32GB) and SSD...
# 1  The item came promptly. From the beginning the touch scr...
# 2  It has already had issues that require repair beyond the...
# 3  Came in evening around 11pm so in thankful USPS was stil...
# 4  This laptop was ok for the price. Lack of USB-C is a pro...

# %%
df_clean = df.drop('reviews', axis=1).copy()
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  I purchased this laptop with upgraded RAM (32GB) and SSD...
# 1       1  The item came promptly. From the beginning the touch scr...
# 2       1  It has already had issues that require repair beyond the...
# 3       4  Came in evening around 11pm so in thankful USPS was stil...
# 4       2  This laptop was ok for the price. Lack of USB-C is a pro...

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here
# lowercase the comments
df_clean['reviews_clean'] = df_clean['reviews_clean'].apply(
    lambda x: ' '.join([x.lower() for x in x.split()]))
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  i purchased this laptop with upgraded ram (32gb) and ssd...
# 1       1  the item came promptly. from the beginning the touch scr...
# 2       1  it has already had issues that require repair beyond the...
# 3       4  came in evening around 11pm so in thankful usps was stil...
# 4       2  this laptop was ok for the price. lack of usb-c is a pro...

# %%
# remove punctuations
df_clean['reviews_clean'] = df_clean['reviews_clean'].str.replace('[^\w\s]', '')
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  i purchased this laptop with upgraded ram 32gb and ssd 1...
# 1       1  the item came promptly from the beginning the touch scre...
# 2       1  it has already had issues that require repair beyond the...
# 3       4  came in evening around 11pm so in thankful usps was stil...
# 4       2  this laptop was ok for the price lack of usbc is a probl...

# %%
# remove numbers
numbers = '0123456789'
df_clean['reviews_clean'] = df_clean['reviews_clean'].apply(
    lambda x: ''.join(x for x in list(x) if x not in numbers))
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  i purchased this laptop with upgraded ram gb and ssd tb ...
# 1       1  the item came promptly from the beginning the touch scre...
# 2       1  it has already had issues that require repair beyond the...
# 3       4  came in evening around pm so in thankful usps was still ...
# 4       2  this laptop was ok for the price lack of usbc is a probl...

# %%
# remove stopwords
stop = stopwords.words('english')
df_clean['reviews_clean'] = df_clean['reviews_clean'].apply(
    lambda x: ' '.join(x for x in x.split() if x not in stop))
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  purchased laptop upgraded ram gb ssd tb arrived near may...
# 1       1  item came promptly beginning touch screen didnt work cou...
# 2       1             already issues require repair beyond inhouse guy
# 3       4  came evening around pm thankful usps still working scrat...
# 4       2  laptop ok price lack usbc problem especially power conne...

# %%
# stemming
st = PorterStemmer()
df_clean['reviews_clean'] = df_clean['reviews_clean'].apply(
    lambda x: " ".join([st.stem(word) for word in x.split()]))
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  purchas laptop upgrad ram gb ssd tb arriv near may fan d...
# 1       1  item came promptli begin touch screen didnt work could l...
# 2       1                 alreadi issu requir repair beyond inhous guy
# 3       4  came even around pm thank usp still work scratch outsid ...
# 4       2  laptop ok price lack usbc problem especi power connector...

# %%
# spelling correction
from textblob import TextBlob
df_clean['reviews_clean'] = df_clean['reviews_clean'].apply(lambda x: str(TextBlob(x).correct()))
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  purchase lawton upgrade ram go sad to arrive near may fa...
# 1       1  item came promptly begin touch screen didn work could li...
# 2       1                 already issue require repair beyond nous guy
# 3       4  came even around pm thank up still work scratch outside ...
# 4       2  lawton ok price lack us problem respect power connection...

# %%
# lemmatization
df['reviews_clean'] = df['reviews_clean'].apply(
    lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df_clean.head()
# Out:
#    rating                                                reviews_clean
# 0       1  purchase lawton upgrade ram go sad to arrive near may fa...
# 1       1  item came promptly begin touch screen didn work could li...
# 2       1                 already issue require repair beyond nous guy
# 3       4  came even around pm thank up still work scratch outside ...
# 4       2  lawton ok price lack us problem respect power connection...

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %% [markdown]
# ## Part 1

# %%
def tag_counts(review):
    tokens = nlp(review)
    pos = [token.pos_ for token in tokens]
    counts = Counter(pos)
    return counts

# %%
df_clean['tags'] = df_clean['reviews_clean'].apply(tag_counts)
df_clean.head()
# Out:
#    rating                                                reviews_clean  \
# 0       1  purchase lawton upgrade ram go sad to arrive near may fa...
# 1       1  item came promptly begin touch screen didn work could li...
# 2       1                 already issue require repair beyond nous guy
# 3       4  came even around pm thank up still work scratch outside ...
# 4       2  lawton ok price lack us problem respect power connection...
#
#                                                           tags
# 0  {'PROPN': 13, 'VERB': 16, 'ADJ': 9, 'PART': 1, 'SCONJ': ...
# 1  {'NOUN': 13, 'VERB': 10, 'ADV': 2, 'PROPN': 2, 'PART': 1...
# 2         {'ADV': 1, 'NOUN': 3, 'VERB': 1, 'ADP': 1, 'ADJ': 1}
# 3  {'VERB': 11, 'ADV': 6, 'ADP': 5, 'NOUN': 18, 'ADJ': 8, '...
# 4  {'PROPN': 2, 'INTJ': 1, 'NOUN': 9, 'VERB': 3, 'PRON': 2,...

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Constituency Parsing

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# import nltk
# benepar.download('benepar_en')

# %%
from benepar.spacy_plugin import BeneparComponent
nlp.add_pipe(BeneparComponent('benepar_en2'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f4f6293a783d> in <module>
#       1 from benepar.spacy_plugin import BeneparComponent
# ----> 2 nlp.add_pipe(BeneparComponent('benepar_en2'))
#
# C:\anaconda3\lib\site-packages\benepar\spacy_plugin.py in __init__(self, filename, batch_size, disable_tagger)
#      76             a tagger built in.
#      77         """
# ---> 78         super(BeneparComponent, self).__init__(filename, batch_size)
#      79         self._do_tagging = (self._provides_tags and not disable_tagger)
#      80
#
# C:\anaconda3\lib\site-packages\benepar\base_parser.py in __init__(self, name, batch_size)
#     195
#     196             if isinstance(model, dict):
# --> 197                 graph_def = tf.GraphDef.FromString(model['model'])
#     198             else:
#     199                 graph_def = tf.GraphDef.FromString(model)
#
# AttributeError: module 'tensorflow' has no attribute 'GraphDef'

# %% [markdown]
# ### Dependency Parsing

# %%
def print_dependencies(reviews, times=None):
    if not times:
        times = reviews.shape[0]
    for i in range(times):
        print(f'review {i+1}:')
        print('----------', end='\n\n')
        for token in nlp(reviews[i]):
            print(token.text,'=>',token.dep_,'=>',token.head.text)
        print()

# %%
print_dependencies(df_clean['reviews_clean'],2)
# Out:
# review 1:
# ----------
#
# purchase => compound => lawton
# lawton => nsubj => upgrade
# upgrade => ROOT => upgrade
# ram => dobj => upgrade
# go => ROOT => go
# sad => acomp => go
# to => aux => arrive
# arrive => xcomp => sad
# near => prep => arrive
# may => compound => fan
# fan => nsubj => die
# die => ROOT => die
# more => amod => june
# june => dobj => die
# one => nummod => year
# year => compound => week
# week => compound => warrant
# purchase => compound => lawton
# lawton => compound => warrant
# warrant => dobj => die
# or => cc => warrant
# or => cc => die
# ran => conj => die
# diagnose => nsubj => said
# said => ROOT => said
# warrant => compound => start
# start => nsubj => end
# end => ccomp => said
# december => npadvmod => end
# well => advmod => december
# want => ROOT => want
# charge => compound => support
# support => nsubj => ask
# ask => ccomp => want
# local => amod => supervisor
# chat => compound => supervisor
# supervisor => nsubj => said
# said => ROOT => said
# one => nummod => weekly
# work => compound => weekly
# weekly => nsubj => buy
# buy => ccomp => said
# well => advmod => buy
# lawton => compound => year
# year => compound => work
# work => dobj => buy
# never => neg => any
# any => ROOT => any
# broken => acl => any
# within => prep => broken
# first => amod => year
# year => pobj => within
# fact => nsubj => buy
# usual => amod => fact
# buy => ROOT => buy
# cheapest => amod => change
# one => nummod => change
# change => dobj => buy
# every => det => year
# year => npadvmod => buy
# first => amod => time
# time => compound => expense
# purchase => compound => expense
# expense => nsubj => think
# one => nummod => expense
# think => ROOT => think
# would => aux => last
# last => ccomp => think
# least => advmod => long
# long => amod => lawton
# lawton => nsubj => support
# ever => advmod => support
# support => ccomp => think
# person => nsubj => blow
# blow => dobj => support
# like => prep => support
#
# review 2:
# ----------
#
# item => nsubj => came
# came => auxpass => begin
# promptly => advmod => begin
# begin => ROOT => begin
# touch => compound => screen
# screen => compound => work
# didn => compound => work
# work => nsubj => live
# could => aux => live
# live => ccomp => begin
# went => ROOT => went
# take => xcomp => went
# class => compound => couldn
# couldn => nsubj => hear
# hear => ccomp => take
# message => compound => pop
# pop => compound => card
# sound => compound => card
# card => nsubj => issue
# wo => aux => issue
# nt => neg => issue
# issue => ccomp => hear
# refund => dobj => issue
# say => ROOT => say
# amazon => compound => response
# response => nsubj => get
# get => ccomp => say
# royal => amod => run
# run => dobj => get
# around => advmod => run

# %%
lengths = df_clean['reviews_clean'].apply(lambda x: len(x))
moderate = list(np.argsort(lengths))[15]
displacy.render(nlp(df_clean['reviews_clean'][moderate]), jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6375618a1803409c9f1e655339ff6dcc-0" class="displacy" width="575" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">fast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">perfect</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">compute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6375618a1803409c9f1e655339ff6dcc-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6375618a1803409c9f1e655339ff6dcc-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6375618a1803409c9f1e655339ff6dcc-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6375618a1803409c9f1e655339ff6dcc-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,91.5 L237,79.5 253,79.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Part 3

# %%
def print_entities(reviews, times=None):
    if not times:
        times = reviews.shape[0]
    for i in range(times):
        print(f'review {i+1}:')
        print('----------', end='\n\n')
        for ent in nlp(reviews[i]).ents:
            print(ent.text, '-->', ent.label_)
        print()

# %%
print_entities(df_clean['reviews_clean'])
# Out:
# review 1:
# ----------
#
# lawton --> PERSON
# june one year week --> DATE
# lawton --> PERSON
# december --> DATE
# one --> CARDINAL
# weekly --> DATE
# lawton year --> DATE
# first year --> DATE
# one --> CARDINAL
# every year --> DATE
# first --> ORDINAL
# one --> CARDINAL
#
# review 2:
# ----------
#
# amazon --> ORG
#
# review 3:
# ----------
#
#
# review 4:
# ----------
#
# amazon --> ORG
#
# review 5:
# ----------
#
# lawton --> ORG
# us --> GPE
#
# review 6:
# ----------
#
#
# review 7:
# ----------
#
# lawton month half --> DATE
# second --> ORDINAL
# one --> CARDINAL
# touchscreen --> CARDINAL
# amazon --> ORG
#
# review 8:
# ----------
#
#
# review 9:
# ----------
#
# year one --> DATE
#
# review 10:
# ----------
#
# lawton random shut --> PERSON
# february --> DATE
# oct --> CARDINAL
#
# review 11:
# ----------
#
# sister cook --> PERSON
# new lawton --> GPE
# lawton --> ORG
# lawton cobb --> PERSON
# space million --> CARDINAL
#
# review 12:
# ----------
#
#
# review 13:
# ----------
#
# far week --> DATE
# one --> CARDINAL
#
# review 14:
# ----------
#
# lawton --> PERSON
# east board --> ORG
#
# review 15:
# ----------
#
# one --> CARDINAL
# mac --> ORG
# touchscreen --> CARDINAL
# lawton cometh --> PRODUCT
#
# review 16:
# ----------
#
#
# review 17:
# ----------
#
#
# review 18:
# ----------
#
# hung june --> ORG
# november --> DATE
#
# review 19:
# ----------
#
#
# review 20:
# ----------
#
# lawton --> ORG
# march --> DATE
# january --> DATE
#
# review 21:
# ----------
#
#
# review 22:
# ----------
#
# dec two day --> DATE
#
# review 23:
# ----------
#
#
# review 24:
# ----------
#
# lawton --> ORG
#
# review 25:
# ----------
#
#
# review 26:
# ----------
#
#
# review 27:
# ----------
#
# january --> DATE
# november --> DATE
# didn --> PERSON
#
# review 28:
# ----------
#
# first --> ORDINAL
# bobtail item --> PERSON
# january --> DATE
#
# review 29:
# ----------
#
# lawton --> PERSON
#
# review 30:
# ----------
#
# lawton --> PERSON
# lawton --> PERSON
# half hour --> TIME
# keyboard stick --> ORG
# one --> CARDINAL
# lawton --> PERSON
#
# review 31:
# ----------
#
# three --> CARDINAL
# three month --> DATE
#
# review 32:
# ----------
#
# lawton --> PERSON
# lawton --> PERSON
# paris --> GPE
#
# review 33:
# ----------
#
# lawton heavier --> PERSON
# carry lawton --> PERSON
#
# review 34:
# ----------
#
#
# review 35:
# ----------
#
# lawton light surf stream --> ORG
#
# review 36:
# ----------
#
# second --> ORDINAL
# second --> ORDINAL
# cup ton --> QUANTITY
# lawton price --> PERSON
# touchscreen later --> DATE
#
# review 37:
# ----------
#
# lawton person --> PERSON
# surf --> ORG
# microsoft --> ORG
# office man hour --> PRODUCT
# one --> CARDINAL
#
# review 38:
# ----------
#
# lawton collegebound engine --> ORG
# lawton --> PERSON
#
# review 39:
# ----------
#
# ten minute --> TIME
# day ago --> DATE
# lawton school --> ORG
#
# review 40:
# ----------
#
# one --> CARDINAL
#
# review 41:
# ----------
#
# great lawton --> PERSON
# two hour --> TIME
#
# review 42:
# ----------
#
#
# review 43:
# ----------
#
# world week --> EVENT
# amazon --> ORG
# one month --> DATE
# amazon --> ORG
# amazon --> ORG
#
# review 44:
# ----------
#
# year old --> DATE
# lawton --> PERSON
# month --> DATE
# one --> CARDINAL
# lawton --> PERSON
# new lawton --> PERSON
# lawton --> PERSON
# bump --> ORG
# complaint --> ORG
#
# review 45:
# ----------
#
#
# review 46:
# ----------
#
# nnnnnnnnnn n n --> ORG
# el que --> ORG
# al insular --> PERSON
# un --> ORG
# al equip --> PERSON
# un --> ORG
# patella azur de error leg del reinicio se autoresuelv per result --> PERSON
# incómodo que --> PERSON
# n n n --> FAC
#
# review 47:
# ----------
#
# one --> CARDINAL
# second --> ORDINAL
#
# review 48:
# ----------
#
# first --> ORDINAL
# one --> CARDINAL
# one --> CARDINAL
#
# review 49:
# ----------
#
# lawton --> ORG
# touchscreen --> CARDINAL
# lawton --> PERSON
# lawton --> PERSON
#
# review 50:
# ----------
#
# didn --> PERSON
# first --> ORDINAL
# man month --> DATE
# one --> CARDINAL
#
# review 51:
# ----------
#
# one --> CARDINAL
#
# review 52:
# ----------
#
# lawton --> PERSON
# man year --> DATE
#
# review 53:
# ----------
#
# lawton --> PERSON
#
# review 54:
# ----------
#
#
# review 55:
# ----------
#
#
# review 56:
# ----------
#
# month --> DATE
#
# review 57:
# ----------
#
#
# review 58:
# ----------
#
#
# review 59:
# ----------
#
#
# review 60:
# ----------
#
# microsoft --> ORG
#
# review 61:
# ----------
#
#
# review 62:
# ----------
#
# one month --> DATE
#
# review 63:
# ----------
#
#
# review 64:
# ----------
#
#
# review 65:
# ----------
#
#
# review 66:
# ----------
#
# lawton week --> DATE
#
# review 67:
# ----------
#
#
# review 68:
# ----------
#
#
# review 69:
# ----------
#
# nnnnnnnnnn --> GPE
# lawton --> PERSON
# leo un temps --> ORG
# pseudo llevarlo santo al --> PERSON
# un --> ORG
# n n n --> FAC
#
# review 70:
# ----------
#
#
# review 71:
# ----------
#
#
# review 72:
# ----------
#
# keyboardwork great --> PERSON
#
# review 73:
# ----------
#
# touchscreen --> CARDINAL
#
# review 74:
# ----------
#
#
# review 75:
# ----------
#
#
# review 76:
# ----------
#
#
# review 77:
# ----------
#
#
# review 78:
# ----------
#
# battery run hour --> TIME
#
# review 79:
# ----------
#
# less memory half --> CARDINAL
#
# review 80:
# ----------
#
# one --> CARDINAL
#
# review 81:
# ----------
#
#
# review 82:
# ----------
#
# month --> DATE
# lawton --> ORG
# lawton --> PERSON
#
# review 83:
# ----------
#
# december --> DATE
#
# review 84:
# ----------
#
# lawton --> PERSON
#
# review 85:
# ----------
#
#
# review 86:
# ----------
#
#
# review 87:
# ----------
#
#
# review 88:
# ----------
#
# argentina --> GPE
# february --> DATE
# march --> DATE
# mimi --> ORG
# month april --> DATE
# argentina first --> ORG
# one day --> DATE
#
# review 89:
# ----------
#
# first --> ORDINAL
#
# review 90:
# ----------
#
#
# review 91:
# ----------
#
# lawton nd --> PERSON
#
# review 92:
# ----------
#
#
# review 93:
# ----------
#
#
# review 94:
# ----------
#
# password sign boom load backlit --> FAC
# lawton --> PERSON
# some hour --> TIME
#
# review 95:
# ----------
#
# didn --> PERSON
# sloooowwww year old --> ORG
# june --> DATE
#
# review 96:
# ----------
#
#
# review 97:
# ----------
#
# lawton map --> PERSON
# day --> DATE
# hour --> TIME
# hour --> TIME
# first --> ORDINAL
# depart hour --> TIME
# english --> LANGUAGE
# first --> ORDINAL
#
# review 98:
# ----------
#
#
# review 99:
# ----------
#
#
# review 100:
# ----------
#
#
# review 101:
# ----------
#
#
# review 102:
# ----------
#
#
# review 103:
# ----------
#
#
# review 104:
# ----------
#
#
# review 105:
# ----------
#
#
# review 106:
# ----------
#
#
# review 107:
# ----------
#
#
# review 108:
# ----------
#
# vasili --> PERSON
# year --> DATE
# one --> CARDINAL
#
# review 109:
# ----------
#
# second --> ORDINAL
# first --> ORDINAL
# one --> CARDINAL
# one --> CARDINAL
# less year --> DATE
#
# review 110:
# ----------
#
# antenna submediocr --> PERSON

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
'''
Write your explanations of the constituency parsing tree and dependency parsing tree here



'''
